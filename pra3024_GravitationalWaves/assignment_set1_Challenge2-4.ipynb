# %%
! pip install -q 'gwosc==0.5.4'
! pip install pycbc
# Out:
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pycbc in /opt/conda/lib/python3.8/site-packages (2.4.0)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.8/site-packages (from pycbc) (1.23.3)
# Requirement already satisfied: cython>=0.29 in /opt/conda/lib/python3.8/site-packages (from pycbc) (0.29.32)
# Requirement already satisfied: scipy>=0.16.0 in /opt/conda/lib/python3.8/site-packages (from pycbc) (1.9.1)
# Requirement already satisfied: astropy!=4.0.5,!=4.2.1,>=2.0.3 in /opt/conda/lib/python3.8/site-packages (from pycbc) (5.2.2)
# Requirement already satisfied: matplotlib>=1.5.1 in /opt/conda/lib/python3.8/site-packages (from pycbc) (3.6.0)
# Requirement already satisfied: mpld3>=0.3 in /opt/conda/lib/python3.8/site-packages (from pycbc) (0.5.10)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.8/site-packages (from pycbc) (9.2.0)
# Requirement already satisfied: h5py!=3.7.0,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from pycbc) (3.10.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from pycbc) (3.1.2)
# Requirement already satisfied: Mako>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from pycbc) (1.2.3)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /opt/conda/lib/python3.8/site-packages (from pycbc) (4.11.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from pycbc) (4.64.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from pycbc) (65.4.1)
# Requirement already satisfied: gwdatafind in /opt/conda/lib/python3.8/site-packages (from pycbc) (1.2.0)
# Requirement already satisfied: pegasus-wms.api>=5.0.6 in /opt/conda/lib/python3.8/site-packages (from pycbc) (5.0.6)
# Requirement already satisfied: python-ligo-lw>=1.7.0 in /opt/conda/lib/python3.8/site-packages (from pycbc) (1.8.3)
# Requirement already satisfied: ligo-segments in /opt/conda/lib/python3.8/site-packages (from pycbc) (1.4.0)
# Requirement already satisfied: lalsuite!=7.2 in /opt/conda/lib/python3.8/site-packages (from pycbc) (7.21)
# Requirement already satisfied: lscsoft-glue>=1.59.3 in /opt/conda/lib/python3.8/site-packages (from pycbc) (3.0.2)
# Requirement already satisfied: pykerr in /opt/conda/lib/python3.8/site-packages (from pycbc) (0.1.0)
# Requirement already satisfied: pyerfa>=2.0 in /opt/conda/lib/python3.8/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (2.0.0.3)
# Requirement already satisfied: PyYAML>=3.13 in /opt/conda/lib/python3.8/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (6.0)
# Requirement already satisfied: packaging>=19.0 in /opt/conda/lib/python3.8/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (21.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4>=4.6.0->pycbc) (2.3.2.post1)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.8/site-packages (from lalsuite!=7.2->pycbc) (2.8.2)
# Requirement already satisfied: importlib-resources>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from lalsuite!=7.2->pycbc) (5.10.0)
# Requirement already satisfied: pyOpenSSL in /opt/conda/lib/python3.8/site-packages (from lscsoft-glue>=1.59.3->pycbc) (23.3.0)
# Requirement already satisfied: pyRXP in /opt/conda/lib/python3.8/site-packages (from lscsoft-glue>=1.59.3->pycbc) (3.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from lscsoft-glue>=1.59.3->pycbc) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.8/site-packages (from Mako>=1.0.1->pycbc) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=1.5.1->pycbc) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=1.5.1->pycbc) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=1.5.1->pycbc) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=1.5.1->pycbc) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=1.5.1->pycbc) (3.0.9)
# Requirement already satisfied: pegasus-wms.common in /opt/conda/lib/python3.8/site-packages (from pegasus-wms.api>=5.0.6->pycbc) (5.0.6)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in /opt/conda/lib/python3.8/site-packages (from gwdatafind->pycbc) (1.1.0)
# Requirement already satisfied: cryptography>=2.3 in /opt/conda/lib/python3.8/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (41.0.5)
# Requirement already satisfied: requests>=2.14 in /opt/conda/lib/python3.8/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.28.1)
# Requirement already satisfied: safe-netrc>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.0.1)
# Requirement already satisfied: scitokens>=1.7.0 in /opt/conda/lib/python3.8/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.8.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from importlib-resources>=1.3.0->lalsuite!=7.2->pycbc) (3.9.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.8/site-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.15.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2023.7.22)
# Requirement already satisfied: PyJWT>=1.6.1 in /opt/conda/lib/python3.8/site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.5.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.21)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Part 1.

# %%
#Loading the data.

import gwosc
import warnings
import pylab
from gwpy.timeseries import TimeSeries

warnings.filterwarnings('ignore')

data = TimeSeries.read('challenge2.gwf', channel="H1:CHALLENGE2")

# %%
#Plotting a q-plot of the data to try and identify the time of the merger. 

import numpy
import matplotlib.pyplot as plt

print(data.sample_rate)  # Checking the sample rate of the data.

q = data.q_transform(frange=(30,350), qrange=(10,15), outseg=(-17,-12))
qplot = q.plot()
ax = qplot.gca()
ax.colorbar(label="Normalised energy")
plt.axvline(x=-14.625, color='orange', linestyle=':')   # Draws a vertical line at the time of the signal.
plt.show()
print("Approximate time of merger: 1980-01-05 23:59:43.75 (UTC)")
# Out:
# 4096.0 Hz
# <Plot size 1200x600 with 2 Axes>
# Approximate time of merger: 1980-01-05 23:59:43.75 (UTC)

# %% [markdown]
# Part 2.

# %%
# Generating a time-domain template waveform for two bodies of mass 30 solar masses.

# %matplotlib inline

from pycbc.waveform import get_td_waveform

hp, hc = get_td_waveform(approximant="SEOBNRv4_opt",
                         mass1=30,
                         mass2=30,
                         delta_t=1.0/4096,
                         f_lower=30)

# Plotting the waveform. 

pylab.figure(figsize=pylab.figaspect(0.4))
pylab.plot(hp.sample_times, hp, label='Plus Polarization')
pylab.plot(hp.sample_times, hc, label='Cross Polarization')
pylab.xlabel('Time (s)')
pylab.ylabel('Strain')
pylab.title("Template Waveform of two Bodies of Mass 30 Solar Masses")
pylab.legend()
pylab.grid()
pylab.show()

# Zooming in near the merger time

pylab.figure(figsize=pylab.figaspect(0.4))
pylab.plot(hp.sample_times, hp, label='Plus Polarization')
pylab.plot(hp.sample_times, hc, label='Cross Polarization')
pylab.xlabel('Time (s)')
pylab.ylabel('Strain')
pylab.xlim(-.01, .01)
pylab.title("Template Waveform of two Bodies of Mass 30 Solar Masses")
pylab.legend()
pylab.grid()
pylab.show()

# %% [markdown]
# Part 3.

# %%
# Calculating and plotting the Power Spectral Density (PSD) of the data.
# Plotted on a log log scale. 

psd = data.psd(fftlength=4, method="median")  # Median because we want the average
plot = psd.plot(yscale='log', xscale='log')   # Log log scale
plt.xlim(20, 2048);       #Plotting from 20 Hz to the Nyquist Frequency
plt.ylim(1e-48,1e-45);
plt.ylabel(f"Power Spectral Density (ct**2Hz**(-1))")
plt.title("PSD of the Data")
plt.show()
# Out:
# <Plot size 640x480 with 1 Axes>

# %% [markdown]
# Part 4. and 5.

# %%
#Calculating the SNR time series.

# %matplotlib inline

from pycbc import frame
from pycbc.catalog import Merger
from pycbc.filter import resample_to_delta_t, highpass
 
# Get the data from the Hanford detector
strain = frame.read_frame('challenge2.gwf', 'H1:CHALLENGE2')

# Remove the low frequency content and downsample the data to 2048Hz
strain = highpass(strain, 15.0)
strain = resample_to_delta_t(strain, 1.0/2048)

pylab.plot(strain.sample_times, strain)
pylab.xlabel('Time (s)')
pylab.ylabel("Strain")
pylab.title("Signal to Noise Ratio of the Data")
pylab.show()

# %%
#Conditioning the data and replotting the conditioned data.

conditioned = strain.crop(2, 2)

pylab.plot(conditioned.sample_times, conditioned)
pylab.xlabel('Time (s)')
pylab.ylabel("Strain")
pylab.title("Signal to Noise Ratio of the Conditioned Data")
pylab.show()

# %%
# Conditioning the PSD and making it a frequency series to allow for an SNR to be found. 

from pycbc.psd import interpolate, inverse_spectrum_truncation

psd = conditioned.psd(4)

psd = interpolate(psd, conditioned.delta_f)

psd = inverse_spectrum_truncation(psd, int(4 * conditioned.sample_rate),
                                  low_frequency_cutoff=15)

# %%
#Resizing the vector to match our conditioned data

from pycbc.waveform import get_td_waveform

m = 30 # Solar masses
hp, hc = get_td_waveform(approximant="SEOBNRv4_opt",
                     mass1=m,
                     mass2=m,
                     delta_t=conditioned.delta_t,
                     f_lower=20)

hp.resize(len(conditioned))

# %%
# Plotting the signal before and after shifting

pylab.figure()
pylab.title('Before shifting')
pylab.plot(hp.sample_times, hp)
pylab.xlabel('Time (s)')
pylab.ylabel('Strain')
pylab.show()

template = hp.cyclic_time_shift(hp.start_time)

pylab.figure()
pylab.title('After shifting')
pylab.plot(template.sample_times, template)
pylab.xlabel('Time (s)')
pylab.ylabel('Strain')
pylab.show()

# %%
#calculating and plotting the matched SNR for the data.

from pycbc.filter import matched_filter
import numpy

snr = matched_filter(template, conditioned,
                     psd=psd, low_frequency_cutoff=20)

snr = snr.crop(4 + 4, 4)

pylab.figure(figsize=[10, 4])
pylab.plot(snr.sample_times, abs(snr))
pylab.ylabel('Strain')
pylab.xlabel('Time (s)')
pylab.title("Matched Signal to Noise Ratio")

pylab.show()

peak = abs(snr).numpy().argmax()
snrp = snr[peak]
time = snr.sample_times[peak]

print("We found a signal at {}s with SNR {}".format(time,abs(snrp)))
# Out:
# We found a signal at -14.6328125s with SNR 22.054545591712564

# %% [markdown]
# The matched filter SNR of the signal is 22.054545591712564.

# %% [markdown]
# All calculation and coding techniques were adapted from the GW_BigData_tutorial-2 found in the module section of the PRA3024 Canvas page.
#
# This tutorial can be found at: https://canvas.maastrichtuniversity.nl/courses/17323/files/3534550/download?download_frd=1
